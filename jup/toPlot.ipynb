# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("../data/obent/train.csv")
test  = pd.read_csv("../data/obent/test.csv")
sample = pd.read_csv("../data/obent/sample.csv")

# %%
train.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
train.shape
# Out:
# (207, 12)

# %%
test.shape
# Out:
# (40, 11)

# %%
test.head()
# Out:
#     datetime week  soldout        name   kcal remarks event  payday weather  \
# 0  2014-10-1    水        1       メンチカツ  420.0     NaN   NaN     NaN       雨
# 1  2014-10-2    木        0   バーベキューチキン  415.0     NaN   NaN     NaN       曇
# 2  2014-10-3    金        0  豚肉のマスタード焼き  405.0     NaN   NaN     NaN      晴れ
# 3  2014-10-6    月        1        麻婆春雨  400.0     NaN   NaN     NaN       雨
# 4  2014-10-7    火        0    厚揚げ肉みそ炒め  430.0     NaN   NaN     NaN      晴れ
#
#   precipitation  temperature
# 0             0         20.2
# 1            --         23.9
# 2            --         28.7
# 3           0.5         21.5
# 4            --         22.1

# %%
test.loc[2, :]
# Out:
# datetime          2014-10-3
# week                      金
# soldout                   0
# name             豚肉のマスタード焼き
# kcal                    405
# remarks                 NaN
# event                   NaN
# payday                  NaN
# weather                  晴れ
# precipitation            --
# temperature            28.7
# Name: 2, dtype: object

# %%
test.describe()
# Out:
#          soldout        kcal  payday  temperature
# count  40.000000   36.000000     2.0    40.000000
# mean    0.425000  421.083333     1.0    18.665000
# std     0.500641   13.626392     0.0     4.401838
# min     0.000000  396.000000     1.0     9.200000
# 25%     0.000000  411.500000     1.0    15.250000
# 50%     0.000000  420.000000     1.0    19.000000
# 75%     1.000000  428.500000     1.0    21.650000
# max     1.000000  460.000000     1.0    28.700000

# %%
test.isna().sum()
# Out:
# datetime          0
# week              0
# soldout           0
# name              0
# kcal              4
# remarks          33
# event            37
# payday           38
# weather           0
# precipitation     0
# temperature       0
# dtype: int64

# %%
sample = pd.read_csv("../data/obent/sample.csv", header=None)

# %%
sample.head()
# Out:
#            0   1
# 0  2014-10-1  24
# 1  2014-10-2  71
# 2  2014-10-3  25
# 3  2014-10-6  32
# 4  2014-10-7  60

# %%
train.describe()
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000

# %%
plt.hist(train['y'])
# Out:
# (array([ 6., 47., 36., 26., 19., 22., 21., 17.,  9.,  4.]),
#  array([ 29. ,  43.2,  57.4,  71.6,  85.8, 100. , 114.2, 128.4, 142.6,
#         156.8, 171. ]),
#  <a list of 10 Patch objects>)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 12 columns):
# datetime         207 non-null object
# y                207 non-null int64
# week             207 non-null object
# soldout          207 non-null int64
# name             207 non-null object
# kcal             166 non-null float64
# remarks          21 non-null object
# event            14 non-null object
# payday           10 non-null float64
# weather          207 non-null object
# precipitation    207 non-null object
# temperature      207 non-null float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 19.5+ KB

# %%
train['y'].describe()
# Out:
# count    207.000000
# mean      86.623188
# std       32.882448
# min       29.000000
# 25%       57.000000
# 50%       78.000000
# 75%      113.000000
# max      171.000000
# Name: y, dtype: float64

# %%
train['y'].mean()
# Out:
# 86.6231884057971

# %%
train['y'].median()
# Out:
# 78.0

# %%
aboub150 = train['y']>150

# %%
aboub150
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 202    False
# 203    False
# 204    False
# 205    False
# 206    False
# Name: y, Length: 207, dtype: bool

# %%
aboub150 = train[train['y']>150]

# %%
aboub150
# Out:
#       datetime    y week  soldout           name  kcal remarks event  payday  \
# 8   2013-11-28  151    木        0          ハンバーグ   NaN     NaN   NaN     NaN
# 10   2013-12-2  151    月        1          マーボ豆腐   NaN     NaN   NaN     NaN
# 11   2013-12-3  153    火        1       厚揚げ豚生姜炒め   NaN     NaN   NaN     NaN
# 12   2013-12-4  151    水        1   クリームチーズ入りメンチ   NaN     NaN   NaN     NaN
# 13   2013-12-5  171    木        0    鶏のカッシュナッツ炒め   NaN     NaN   NaN     NaN
# 15   2013-12-9  165    月        1     ハンバーグデミソース   NaN     NaN   NaN     NaN
# 16  2013-12-10  155    火        0  やわらかロースのサムジョン   NaN     NaN   NaN     1.0
# 17  2013-12-11  157    水        0           五目御飯   NaN     NaN   NaN     NaN
# 20  2013-12-16  160    月        0      カキフライタルタル   NaN     NaN   NaN     NaN
# 23  2013-12-19  151    木        0        ポーク味噌焼き   NaN     NaN   NaN     NaN
#
#    weather precipitation  temperature
# 8       薄曇            --         17.7
# 10      快晴            --         13.8
# 11      快晴            --         13.9
# 12      晴れ            --         13.5
# 13      快晴            --         13.8
# 15       曇            --          9.1
# 16       曇           0.5          7.1
# 17       曇            --         11.0
# 20      快晴            --         11.3
# 23       雨           0.5          6.8

# %%
mon = train[train['week']=='月']

# %%
train[train['week'] == '火'].sort_values(by='y')
# Out:
#        datetime    y week  soldout           name   kcal remarks event  \
# 206   2014-9-30   40    火        0   鶏肉とカシューナッツ炒め  398.0     NaN   NaN
# 176   2014-8-12   40    火        1         厚切ハムカツ  400.0     NaN   NaN
# 157   2014-7-15   51    火        0      豚冷シャブ野菜添え  324.0     NaN   NaN
# 166   2014-7-29   52    火        0      バーベキューチキン  449.0     NaN   NaN
# 178   2014-8-19   53    火        1          牛スキヤキ  385.0     NaN   NaN
# 161   2014-7-22   53    火        0       チンジャオロース  409.0     NaN   NaN
# 147    2014-7-1   54    火        0    カレイ唐揚げ夏野菜あん  362.0     NaN   NaN
# 171    2014-8-5   54    火        1       鶏肉のカレー唐揚  400.0     NaN   NaN
# 132   2014-6-10   56    火        0    カレイ唐揚げ野菜餡かけ  426.0     NaN   NaN
# 152    2014-7-8   56    火        0        かじきの甘辛煮  370.0     NaN   NaN
# 197   2014-9-16   56    火        0       チーズメンチカツ  438.0     NaN   NaN
# 127    2014-6-3   59    火        0      ゴーヤチャンプルー  418.0     NaN   NaN
# 142   2014-6-24   61    火        0      鶏のトマトシチュー  430.0     NaN   NaN
# 137   2014-6-17   63    火        0    ポークソテー韓国ソース  427.0     NaN   NaN
# 193    2014-9-9   63    火        0     ハンバーグデミソース  460.0     NaN   NaN
# 188    2014-9-2   68    火        1        名古屋味噌カツ  440.0   手作りの味   NaN
# 183   2014-8-26   68    火        0         キーマカレー  400.0     NaN   NaN
# 112   2014-5-13   70    火        1    白身魚唐揚げ野菜餡かけ  428.0     NaN   NaN
# 117   2014-5-20   71    火        0       鶏の味噌漬け焼き  425.0     NaN   NaN
# 80    2014-3-25   77    火        0        手作りひれかつ  407.0     NaN   NaN
# 100   2014-4-22   78    火        1          マーボ豆腐  382.0     NaN   NaN
# 122   2014-5-27   79    火        0        牛肉すき焼き風  423.0     NaN   NaN
# 95    2014-4-15   82    火        0        ポーク生姜焼き  370.0     NaN   NaN
# 71    2014-3-11   89    火        0           肉じゃが  397.0     NaN   NaN
# 76    2014-3-18   90    火        1     チーズ入りハンバーグ  400.0     NaN   NaN
# 90     2014-4-8   96    火        1       肉団子のシチュー  353.0     NaN   NaN
# 56    2014-2-18   99    火        0   海老フライとホタテ串カツ  426.0     NaN   NaN
# 66     2014-3-4  100    火        1            回鍋肉  413.0     NaN   NaN
# 1    2013-11-19  101    火        1        手作りヒレカツ    NaN     NaN   NaN
# 61    2014-2-25  104    火        0          マーボ豆腐  396.0     NaN   NaN
# 42    2014-1-28  120    火        0      海老フライタルタル  445.0     NaN   NaN
# 47     2014-2-4  121    火        1       さわら焼味噌掛け  430.0     NaN   NaN
# 25   2013-12-24  122    火        0      さっくりメンチカツ    NaN     NaN   NaN
# 85     2014-4-1  125    火        1          メンチカツ  377.0     NaN   NaN
# 37    2014-1-21  129    火        1        サバ焼味噌掛け  447.0     NaN   NaN
# 32    2014-1-14  129    火        1    鶏の照り焼きマスタード  376.0     NaN   NaN
# 28     2014-1-7  131    火        0   カレー入りソーセージカツ  404.0     NaN   NaN
# 21   2013-12-17  145    火        0        手作りヒレカツ    NaN     NaN  ママの会
# 6    2013-11-26  145    火        0       豚のスタミナ炒め    NaN     NaN   NaN
# 11    2013-12-3  153    火        1       厚揚げ豚生姜炒め    NaN     NaN   NaN
# 16   2013-12-10  155    火        0  やわらかロースのサムジョン    NaN     NaN   NaN
#
#      payday weather precipitation  temperature
# 206     NaN      快晴            --         28.1
# 176     NaN       雨             0         29.4
# 157     NaN      晴れ            --         30.3
# 166     NaN      晴れ            --         30.4
# 178     NaN      晴れ            --         33.3
# 161     NaN      晴れ            --         30.2
# 147     NaN       曇            --         28.3
# 171     NaN      快晴            --         34.3
# 132     1.0       曇            --         25.5
# 152     NaN      晴れ            --         29.7
# 197     NaN      晴れ            --         28.8
# 127     NaN      薄曇            --         27.0
# 142     NaN       曇             0         23.7
# 137     NaN      薄曇            --         27.6
# 193     NaN      晴れ            --         26.8
# 188     NaN      晴れ            --         29.1
# 183     NaN       雨             0         26.2
# 112     NaN       雨             0         18.6
# 117     NaN      薄曇            --         23.9
# 80      NaN      快晴            --         18.9
# 100     NaN       曇            --         18.8
# 122     NaN       曇            --         23.7
# 95      NaN      快晴            --         19.7
# 71      NaN      快晴            --          8.7
# 76      NaN      晴れ            --         18.9
# 90      NaN      快晴            --         20.1
# 56      NaN      晴れ            --          6.8
# 66      NaN      晴れ            --          8.3
# 1       NaN      快晴            --         17.0
# 61      NaN      快晴            --         10.5
# 42      NaN      快晴            --         12.6
# 47      NaN       雨             0          3.8
# 25      NaN      快晴            --         11.5
# 85      NaN      薄曇            --         16.1
# 37      NaN      快晴            --         10.4
# 32      NaN      晴れ            --          5.8
# 28      NaN      快晴            --          7.3
# 21      NaN       曇            --         10.8
# 6       NaN      快晴            --         17.9
# 11      NaN      快晴            --         13.9
# 16      1.0       曇           0.5          7.1

# %%
train[train['week'] == '火'].sort_values(by='y',ascending=False)
# Out:
#        datetime    y week  soldout           name   kcal remarks event  \
# 16   2013-12-10  155    火        0  やわらかロースのサムジョン    NaN     NaN   NaN
# 11    2013-12-3  153    火        1       厚揚げ豚生姜炒め    NaN     NaN   NaN
# 21   2013-12-17  145    火        0        手作りヒレカツ    NaN     NaN  ママの会
# 6    2013-11-26  145    火        0       豚のスタミナ炒め    NaN     NaN   NaN
# 28     2014-1-7  131    火        0   カレー入りソーセージカツ  404.0     NaN   NaN
# 32    2014-1-14  129    火        1    鶏の照り焼きマスタード  376.0     NaN   NaN
# 37    2014-1-21  129    火        1        サバ焼味噌掛け  447.0     NaN   NaN
# 85     2014-4-1  125    火        1          メンチカツ  377.0     NaN   NaN
# 25   2013-12-24  122    火        0      さっくりメンチカツ    NaN     NaN   NaN
# 47     2014-2-4  121    火        1       さわら焼味噌掛け  430.0     NaN   NaN
# 42    2014-1-28  120    火        0      海老フライタルタル  445.0     NaN   NaN
# 61    2014-2-25  104    火        0          マーボ豆腐  396.0     NaN   NaN
# 1    2013-11-19  101    火        1        手作りヒレカツ    NaN     NaN   NaN
# 66     2014-3-4  100    火        1            回鍋肉  413.0     NaN   NaN
# 56    2014-2-18   99    火        0   海老フライとホタテ串カツ  426.0     NaN   NaN
# 90     2014-4-8   96    火        1       肉団子のシチュー  353.0     NaN   NaN
# 76    2014-3-18   90    火        1     チーズ入りハンバーグ  400.0     NaN   NaN
# 71    2014-3-11   89    火        0           肉じゃが  397.0     NaN   NaN
# 95    2014-4-15   82    火        0        ポーク生姜焼き  370.0     NaN   NaN
# 122   2014-5-27   79    火        0        牛肉すき焼き風  423.0     NaN   NaN
# 100   2014-4-22   78    火        1          マーボ豆腐  382.0     NaN   NaN
# 80    2014-3-25   77    火        0        手作りひれかつ  407.0     NaN   NaN
# 117   2014-5-20   71    火        0       鶏の味噌漬け焼き  425.0     NaN   NaN
# 112   2014-5-13   70    火        1    白身魚唐揚げ野菜餡かけ  428.0     NaN   NaN
# 183   2014-8-26   68    火        0         キーマカレー  400.0     NaN   NaN
# 188    2014-9-2   68    火        1        名古屋味噌カツ  440.0   手作りの味   NaN
# 137   2014-6-17   63    火        0    ポークソテー韓国ソース  427.0     NaN   NaN
# 193    2014-9-9   63    火        0     ハンバーグデミソース  460.0     NaN   NaN
# 142   2014-6-24   61    火        0      鶏のトマトシチュー  430.0     NaN   NaN
# 127    2014-6-3   59    火        0      ゴーヤチャンプルー  418.0     NaN   NaN
# 132   2014-6-10   56    火        0    カレイ唐揚げ野菜餡かけ  426.0     NaN   NaN
# 152    2014-7-8   56    火        0        かじきの甘辛煮  370.0     NaN   NaN
# 197   2014-9-16   56    火        0       チーズメンチカツ  438.0     NaN   NaN
# 147    2014-7-1   54    火        0    カレイ唐揚げ夏野菜あん  362.0     NaN   NaN
# 171    2014-8-5   54    火        1       鶏肉のカレー唐揚  400.0     NaN   NaN
# 161   2014-7-22   53    火        0       チンジャオロース  409.0     NaN   NaN
# 178   2014-8-19   53    火        1          牛スキヤキ  385.0     NaN   NaN
# 166   2014-7-29   52    火        0      バーベキューチキン  449.0     NaN   NaN
# 157   2014-7-15   51    火        0      豚冷シャブ野菜添え  324.0     NaN   NaN
# 176   2014-8-12   40    火        1         厚切ハムカツ  400.0     NaN   NaN
# 206   2014-9-30   40    火        0   鶏肉とカシューナッツ炒め  398.0     NaN   NaN
#
#      payday weather precipitation  temperature
# 16      1.0       曇           0.5          7.1
# 11      NaN      快晴            --         13.9
# 21      NaN       曇            --         10.8
# 6       NaN      快晴            --         17.9
# 28      NaN      快晴            --          7.3
# 32      NaN      晴れ            --          5.8
# 37      NaN      快晴            --         10.4
# 85      NaN      薄曇            --         16.1
# 25      NaN      快晴            --         11.5
# 47      NaN       雨             0          3.8
# 42      NaN      快晴            --         12.6
# 61      NaN      快晴            --         10.5
# 1       NaN      快晴            --         17.0
# 66      NaN      晴れ            --          8.3
# 56      NaN      晴れ            --          6.8
# 90      NaN      快晴            --         20.1
# 76      NaN      晴れ            --         18.9
# 71      NaN      快晴            --          8.7
# 95      NaN      快晴            --         19.7
# 122     NaN       曇            --         23.7
# 100     NaN       曇            --         18.8
# 80      NaN      快晴            --         18.9
# 117     NaN      薄曇            --         23.9
# 112     NaN       雨             0         18.6
# 183     NaN       雨             0         26.2
# 188     NaN      晴れ            --         29.1
# 137     NaN      薄曇            --         27.6
# 193     NaN      晴れ            --         26.8
# 142     NaN       曇             0         23.7
# 127     NaN      薄曇            --         27.0
# 132     1.0       曇            --         25.5
# 152     NaN      晴れ            --         29.7
# 197     NaN      晴れ            --         28.8
# 147     NaN       曇            --         28.3
# 171     NaN      快晴            --         34.3
# 161     NaN      晴れ            --         30.2
# 178     NaN      晴れ            --         33.3
# 166     NaN      晴れ            --         30.4
# 157     NaN      晴れ            --         30.3
# 176     NaN       雨             0         29.4
# 206     NaN      快晴            --         28.1

# %%
train[train['week'] == '月'].mean()
# Out:
# y               94.051282
# soldout          0.487179
# kcal           398.970588
# payday           1.000000
# temperature     19.656410
# dtype: float64

# %%
trainMon = train[train['week'] == '月']

# %%
trainMon.head()
# Out:
#       datetime    y week  soldout        name  kcal remarks event  payday  \
# 0   2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 5   2013-11-25  135    月        1        鶏の唐揚   NaN     NaN   NaN     NaN
# 10   2013-12-2  151    月        1       マーボ豆腐   NaN     NaN   NaN     NaN
# 15   2013-12-9  165    月        1  ハンバーグデミソース   NaN     NaN   NaN     NaN
# 20  2013-12-16  160    月        0   カキフライタルタル   NaN     NaN   NaN     NaN
#
#    weather precipitation  temperature
# 0       快晴            --         19.8
# 5        曇            --         14.6
# 10      快晴            --         13.8
# 15       曇            --          9.1
# 20      快晴            --         11.3

# %%
train['temperature'].mean()
# Out:
# 19.252173913043478

# %%
train[train['temperature']>train['temperature'].mean()]
# Out:
#        datetime   y week  soldout          name   kcal          remarks  \
# 0    2013-11-18  90    月        0      厚切りイカフライ    NaN              NaN
# 90     2014-4-8  96    火        1      肉団子のシチュー  353.0              NaN
# 92    2014-4-10  87    木        0   鶏の唐揚げおろしソース  362.0              NaN
# 95    2014-4-15  82    火        0       ポーク生姜焼き  370.0              NaN
# 96    2014-4-16  57    水        0  カレイ唐揚げ野菜あんかけ  330.0              NaN
# ..          ...  ..  ...      ...           ...    ...              ...
# 202   2014-9-24  59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203   2014-9-25  50    木        0       牛カルビ焼き肉  394.0              NaN
# 204   2014-9-26  45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205   2014-9-29  56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206   2014-9-30  40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature
# 0              NaN     NaN      快晴            --         19.8
# 90             NaN     NaN      快晴            --         20.1
# 92             NaN     1.0      晴れ            --         21.3
# 95             NaN     NaN      快晴            --         19.7
# 96             NaN     NaN      薄曇            --         21.5
# ..             ...     ...     ...           ...          ...
# 202            NaN     NaN       曇             0         24.8
# 203            NaN     NaN       曇             0         25.4
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1
# 205            NaN     NaN      快晴            --         26.6
# 206            NaN     NaN      快晴            --         28.1
#
# [107 rows x 12 columns]

# %%
train[['y']['week']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-de3e9082412e> in <module>
# ----> 1 train[['y']['week']]
#
# TypeError: list indices must be integers or slices, not str

# %%
train[['y','week']]
# Out:
#        y week
# 0     90    月
# 1    101    火
# 2    118    水
# 3    120    木
# 4    130    金
# ..   ...  ...
# 202   59    水
# 203   50    木
# 204   45    金
# 205   56    月
# 206   40    火
#
# [207 rows x 2 columns]

# %%
train[['y','week','temperature']]
# Out:
#        y week  temperature
# 0     90    月         19.8
# 1    101    火         17.0
# 2    118    水         15.5
# 3    120    木         15.2
# 4    130    金         16.1
# ..   ...  ...          ...
# 202   59    水         24.8
# 203   50    木         25.4
# 204   45    金         27.1
# 205   56    月         26.6
# 206   40    火         28.1
#
# [207 rows x 3 columns]

# %%
plt.plot(train['datetime'],train['y'])

# %%
plt.figure(figsize=(12,4))
plt.plot(train['datetime'],train['y'])

# %%
train['y'].plot(figsize=(12,4))

# %%
train[['y','week']].boxplot(by='week')
# Out:
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27700 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 28779 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 37329 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 26376 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 26408 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 27700 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 28779 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 37329 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %%
ax = train['temperature'].plot(title='kion')

# %%
ax.set_xlabel()

# %%
plt.axvline(x=train['kcal'].mean(), color='red')
train['kcal'].plot.hist()

# %%
train[["y", 'weather']].boxplot(by="weather")
# Out:
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 24555 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 26311 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 38632 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:176: RuntimeWarning: Glyph 38634 missing from current font.
#   font.load_char(ord(s), flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 38647 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/ma/.bin/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 38651 missing from current font.
#   font.set_text(s, 0, flags=flags)
